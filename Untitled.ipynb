# %% [markdown]
# <a href="https://colab.research.google.com/github/NTNTP/-home-noam-Mypython-.git-/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np

print("Importé")
# Out:
# Importé
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("/content/gdrive/My Drive/data.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
data.describe(include='all')#Analyser ce jeu de données
# Out:
#           Unnamed: 0             ID  ...    GKReflexes  Release Clause
# count   18207.000000   18207.000000  ...  18159.000000           16643
# unique           NaN            NaN  ...           NaN            1244
# top              NaN            NaN  ...           NaN           €1.1M
# freq             NaN            NaN  ...           NaN             557
# mean     9103.000000  214298.338606  ...     16.710887             NaN
# std      5256.052511   29965.244204  ...     17.955119             NaN
# min         0.000000      16.000000  ...      1.000000             NaN
# 25%      4551.500000  200315.500000  ...      8.000000             NaN
# 50%      9103.000000  221759.000000  ...     11.000000             NaN
# 75%     13654.500000  236529.500000  ...     14.000000             NaN
# max     18206.000000  246620.000000  ...     94.000000             NaN
#
# [11 rows x 89 columns]

# %%
import math
x = float('nan')
math.isnan(x)
data.dropna()   
data.fillna("?")
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...          8         €226.5M
# 1               1   20801  ...         11         €127.1M
# 2               2  190871  ...         11         €228.1M
# 3               3  193080  ...         94         €138.6M
# 4               4  192985  ...         13         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...          9           €143K
# 18203       18203  243165  ...         12           €113K
# 18204       18204  241638  ...         13           €165K
# 18205       18205  246268  ...          9           €143K
# 18206       18206  246269  ...          9           €165K
#
# [18207 rows x 89 columns]

# %% [markdown]
# #Traiter les NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %% [markdown]
# #Analyser ce jeu de données

# %%
data.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %% [markdown]
# #Analyser ce jeu de données

# %%
import seaborn as sns 

sns.set()
sns.relplot(x="Club", y="Name", col="Nationality",
            data=data);

# %% [markdown]
# Ce Graphique repésentes le nombre de joueurs dans le monde en fonction de leurs Nationalité

# %%
sns.distplot(data.Age)

# %% [markdown]
# Le Graphique permet de voir la moyenne d'age de tous les footballeurs

# %%
mask2 = (data.Overall >= 90)#Le masque permet de garder les lignes du dataset des joueurs les plus forts du Jeu FIFA 19 avec un général supérieur à 90
sns.boxplot(x='Overall', y='Name', data=df[mask2])

# %% [markdown]
# #Le graphique permet de voir quels joueurs sont les plus fort par rapport à leurs note générale dans le jeu

# %%
filtre2 = data.query ('(Nationality == "French") & (Overall >= "88")')
sns.catplot( x='Nationality', y='Overall', data=filtre2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a2dc7676a3f3> in <module>()
# ----> 1 filtre2 = data.query ('(Nationality == "French") & (Overall >= "88")')
#       2 sns.catplot( x='Nationality', y='Overall', data=filtre2)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
# ...
